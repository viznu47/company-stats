# %% [markdown]
# Importing libraries

# %%
import findspark
findspark.init('/usr/spark2.4.3')

# %%
from pyspark.sql import SparkSession

# %%
ss = SparkSession.builder.appName("test").getOrCreate()

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import *
from pyspark.sql.window import *
from pyspark.sql.types import *

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Loading data

# %%
file_location = "/user/kolpurath6035/registered_companies.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = ss.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)
#.show(n =5, truncate = False)

# %% [markdown]
# Preprocessing

# %%
# null values
column_counts = df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns])

rows = column_counts.collect()
for row in rows:
    for column, null_count in row.asDict().items():
        print(f"{column}: {null_count}")
    print()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER: 0
# COMPANY_NAME: 0
# COMPANY_STATUS: 0
# COMPANY_CLASS: 5078
# COMPANY_CATEGORY: 5085
# COMPANY_SUB_CATEGORY: 5090
# date_of_registration: 2525
# REGISTERED_STATE: 0
# AUTHORIZED_CAP: 0
# PAIDUP_CAPITAL: 2075
# INDUSTRIAL_CLASS: 4811
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN: 12
# REGISTERED_OFFICE_ADDRESS: 15259
# REGISTRAR_OF_COMPANIES: 42014
# EMAIL_ADDR: 369507
# latest_year_annual_return: 838571
# LATEST_YEAR_FINANCIAL_STATEMENT: 827419

# %%
# data types of each columns
df.printSchema()
# Out:
# root
#  |-- CORPORATE_IDENTIFICATION_NUMBER: string (nullable = true)
#  |-- COMPANY_NAME: string (nullable = true)
#  |-- COMPANY_STATUS: string (nullable = true)
#  |-- COMPANY_CLASS: string (nullable = true)
#  |-- COMPANY_CATEGORY: string (nullable = true)
#  |-- COMPANY_SUB_CATEGORY: string (nullable = true)
#  |-- date_of_registration: string (nullable = true)
#  |-- REGISTERED_STATE: string (nullable = true)
#  |-- AUTHORIZED_CAP: string (nullable = true)
#  |-- PAIDUP_CAPITAL: integer (nullable = true)
#  |-- INDUSTRIAL_CLASS: string (nullable = true)
#  |-- PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN: string (nullable = true)
#  |-- REGISTERED_OFFICE_ADDRESS: string (nullable = true)
#  |-- REGISTRAR_OF_COMPANIES: string (nullable = true)
#  |-- EMAIL_ADDR: string (nullable = true)
#  |-- latest_year_annual_return: string (nullable = true)
#  |-- LATEST_YEAR_FINANCIAL_STATEMENT: string (nullable = true)

# %%
# changing the data type of date
from pyspark.sql import functions as F

df = df.withColumn("date_of_registration",F.date_format(F.to_date("date_of_registration", "dd-MM-yyyy"), "yyyy-MM-dd"))
df = df.withColumn("latest_year_annual_return",F.date_format(F.to_date("latest_year_annual_return", "dd-MM-yyyy"), "yyyy-MM-dd"))

df = df.withColumn("PAIDUP_CAPITAL",df.PAIDUP_CAPITAL.cast(IntegerType())) # changing string to int
df.select("date_of_registration").printSchema()
# Out:
# root
#  |-- date_of_registration: string (nullable = true)

# %%
# counting no. of rows
df.count()
# Out:
# 1992170

# %%
# column names
df.columns
# Out:
# ['CORPORATE_IDENTIFICATION_NUMBER',
#  'COMPANY_NAME',
#  'COMPANY_STATUS',
#  'COMPANY_CLASS',
#  'COMPANY_CATEGORY',
#  'COMPANY_SUB_CATEGORY',
#  'date_of_registration',
#  'REGISTERED_STATE',
#  'AUTHORIZED_CAP',
#  'PAIDUP_CAPITAL',
#  'INDUSTRIAL_CLASS',
#  'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN',
#  'REGISTERED_OFFICE_ADDRESS',
#  'REGISTRAR_OF_COMPANIES',
#  'EMAIL_ADDR',
#  'latest_year_annual_return',
#  'LATEST_YEAR_FINANCIAL_STATEMENT']

# %%
df.describe('PAIDUP_CAPITAL','AUTHORIZED_CAP').show()
# Out:
# +-------+-------------------+--------------------+
# |summary|     PAIDUP_CAPITAL|      AUTHORIZED_CAP|
# +-------+-------------------+--------------------+
# |  count|            1990095|             1992170|
# |   mean|  6626710.304396021|4.2385082192709126E7|
# | stddev|5.772859423538962E7|2.9605622147065825E9|
# |    min|                  0|                 0.0|
# |    max|         2146500000|      999999999990.0|
# +-------+-------------------+--------------------+

# %% [markdown]
# 1. Based on the sector display the number of companies

# %%
# query 1
pandas_df = df.groupBy("COMPANY_CLASS").agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("no_of_companies"))
pandas_df = pandas_df.dropna()
pandas_df.show()
# Out:
# +--------------------+---------------+
# |       COMPANY_CLASS|no_of_companies|
# +--------------------+---------------+
# |              Public|         137612|
# |             Private|        1819264|
# |Private(One Perso...|          30216|
# +--------------------+---------------+

# %%
pandas_df.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 2. List the number of companies that had been registered in each decade

# %%
# query 2

dec = df.groupBy(year(col("DATE_OF_REGISTRATION")).alias("year")).agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("count")).orderBy(year(col("DATE_OF_REGISTRATION")))

dec_df = dec.withColumn("decade", floor(col("year") / 10)*10)

cnt = dec_df.groupBy(col("decade")).agg(sum(col("count")).alias("count")).orderBy(col("decade"))

cnt.show()
# Out:
# +------+------+
# |decade| count|
# +------+------+
# |  null|  2525|
# |  1850|     1|
# |  1860|     3|
# |  1870|    24|
# |  1880|    36|
# |  1890|    57|
# |  1900|   887|
# |  1910|   934|
# |  1920|  1827|
# |  1930|  3378|
# |  1940| 10808|
# |  1950|  9475|
# |  1960| 11818|
# |  1970| 30666|
# |  1980|143785|
# |  1990|344661|
# |  2000|439820|
# |  2010|978716|
# |  2020| 12747|
# |  5600|     1|
# +------+------+
# only showing top 20 rows

# %%
cnt.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 3. Find top 5 companies with highest paid up capital as a list in each leap year after 2000

# %%
# query 3

def checkLeap(y):
    if y is not None:
        y = int(y)
        if y >= 2000:
            if (((y%4 == 0) & (y%100 != 0)) | (y%400 == 0)):
                return True
            else:
                return False
        else:
            return False
    else:
        return False
    
leap =  udf(checkLeap, BooleanType())

leap_df = df.select(year("date_of_registration").alias("year"),"COMPANY_NAME","PAIDUP_CAPITAL").filter(leap(year(col("date_of_registration"))) == True)

leap_df = leap_df.withColumn("PAIDUP_CAPITAL",leap_df.PAIDUP_CAPITAL.cast(IntegerType())) # changing string to int

partition = Window.partitionBy("year").orderBy(desc("PAIDUP_CAPITAL"))
new_leap = leap_df.withColumn("rank", dense_rank().over(partition))

new_leap = new_leap.filter((col("rank").between(1,5))).orderBy("year","rank")
new_leap.show(2000)
# Out:
# +----+--------------------+--------------+----+
# |year|        COMPANY_NAME|PAIDUP_CAPITAL|rank|
# +----+--------------------+--------------+----+
# |2000|RELOGISTICS INFRA...|    2101913000|   1|
# |2000|NANDI ECONOMIC CO...|    2090466920|   2|
# |2000|MW UNITEXX LIMITE...|    2087292760|   3|
# |2000|NARAYANA HRUDAYAL...|    2043608040|   4|
# |2000|PIPAVAV RAILWAY C...|    1960000200|   5|
# |2004|EON HADAPSAR INFR...|    2131500000|   1|
# |2004|SANYO BPL PRIVATE...|    2089333780|   2|
# |2004|GKC PROJECTS LIMI...|    2050787020|   3|
# |2004|FIRST FORGE LIMIT...|    2033333330|   4|
# |2004|FIRESTAR INTERNAT...|    1946501420|   5|
# |2008|BOSCH AUTOMOTIVE ...|    2130769230|   1|
# |2008|COFFEE DAY ENTERP...|    2112517190|   2|
# |2008|ASHLEY POWERTRAIN...|    2091004190|   3|
# |2008|KERALA STATE INFO...|    2049592000|   4|
# |2008|RAJAHMUNDRY GODAV...|    2039589000|   5|
# |2012|NACHI TECHNOLOGY ...|    2100000000|   1|
# |2012|HEXA INDUSTRIES P...|    2091810000|   2|
# |2012|MYTRAH VAYU (MANJ...|    2084506870|   3|
# |2012|SAHARA PURE EATAB...|    2050500000|   4|
# |2012|SEIREN INDIA PRIV...|    2050000000|   5|
# |2016|CG TOLLWAY LIMITE...|    2035000000|   1|
# |2016|ILJIN GLOBAL INDI...|    2018850000|   2|
# |2016|BELAGAVI SMART CI...|    2000000000|   3|
# |2016|UJJAIN SMART CITY...|    2000000000|   3|
# |2016|COCHIN SMART MISS...|    2000000000|   3|
# |2016|UDAIPUR SMART CIT...|    2000000000|   3|
# |2016|JABALPUR SMART CI...|    2000000000|   3|
# |2016|NAGPUR SMART AND ...|    2000000000|   3|
# |2016|SMART CITY AHMEDA...|    2000000000|   3|
# |2016|GWALIOR SMART CIT...|    2000000000|   3|
# |2016|JSW PAINTS PRIVAT...|    2000000000|   3|
# |2016|INDOSTAR HOME FIN...|    2000000000|   3|
# |2016|KAKINADA SMART CI...|    2000000000|   3|
# |2016|GREATER VISAKHAPA...|    2000000000|   3|
# |2016|INDORE SMART CITY...|    2000000000|   3|
# |2016|DAVANAGERE SMART ...|    2000000000|   3|
# |2016|SURAT SMART CITY ...|    2000000000|   3|
# |2016|JAIPUR SMART CITY...|    2000000000|   3|
# |2016|KOTA SMART CITY L...|    2000000000|   3|
# |2016|BHOPAL SMART CITY...|    2000000000|   3|
# |2016|CENTRUM HOUSING F...|    1982177860|   4|
# |2016|PUNE SMART CITY D...|    1960000000|   5|
# |2020|ATLBATTERY TECHNO...|    1793500000|   1|
# |2020|BHARAT CONSTRUCTI...|     762674880|   2|
# |2020|HENGLI HYDRAULIC ...|     560000000|   3|
# |2020|XIYIN INDIA PRIVA...|     360000000|   4|
# |2020|MUFG ENTERPRISE S...|     312000000|   5|
# |5600|WHITTLE SPINNING ...|             0|   1|
# |9076|958U INFOTECH PRI...|             0|   1|
# +----+--------------------+--------------+----+

# %%
new_leap.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 4. Find top 5 companies that has highest paid up capital in each state

# %%
# query 4

cmp = df.select("REGISTERED_STATE","COMPANY_NAME","PAIDUP_CAPITAL")
part = Window.partitionBy("REGISTERED_STATE").orderBy(desc("PAIDUP_CAPITAL"))

new_comp = cmp.withColumn("rank", dense_rank().over(part))
new_comp = new_comp.filter((col("rank").between(1,5)))

new_comp.show(2000)
# Out:
# +--------------------+--------------------+--------------+----+
# |    REGISTERED_STATE|        COMPANY_NAME|PAIDUP_CAPITAL|rank|
# +--------------------+--------------------+--------------+----+
# |            Nagaland|NAGALAND PULP & P...|    1177500700|   1|
# |            Nagaland|NAGALAND INDUSTRI...|     232001800|   2|
# |            Nagaland|SANGRAHALAYA TIMB...|     200100000|   3|
# |            Nagaland|HOTAHOTI WOOD PRO...|     199999600|   4|
# |            Nagaland|SHYAMA POWER INDI...|     150761000|   5|
# |           Karnataka|BOSCH AUTOMOTIVE ...|    2130769230|   1|
# |           Karnataka|MODEL INFRA CORPO...|    2126211590|   2|
# |           Karnataka|TECHNOTRENDS AUTO...|    2115100000|   3|
# |           Karnataka|COFFEE DAY ENTERP...|    2112517190|   4|
# |           Karnataka|DHRUVI SECURITIES...|    2100597940|   5|
# |Dadra and Nagra H...|K-LIFESTYLE & IND...|    1017804000|   1|
# |Dadra and Nagra H...|JBF INDUSTRIES LI...|     967789390|   2|
# |Dadra and Nagra H...|DNH POWER DISTRIB...|     800000000|   3|
# |Dadra and Nagra H...|ACTIF CORPORATION...|     712571550|   4|
# |Dadra and Nagra H...|GLOBAL SOFTECH LI...|     650000000|   5|
# |              Kerala|TABLEZ FOOD COMPA...|    2115285950|   1|
# |              Kerala|DEWA PROJECTS PRI...|    2073030000|   2|
# |              Kerala|KERALA STATE INFO...|    2049592000|   3|
# |              Kerala|KOSAMATTAM FINANC...|    2036017700|   4|
# |              Kerala|KERALA STATE ELEC...|    2035518100|   5|
# |          Tamil Nadu|SHRIRAM HOUSING F...|    2141600000|   1|
# |          Tamil Nadu|ONEHUB (CHENNAI) ...|    2122832070|   2|
# |          Tamil Nadu|DORMAKABA INDIA P...|    2112070120|   3|
# |          Tamil Nadu|COASTAL ENERGEN P...|    2109042350|   4|
# |          Tamil Nadu|MEDALL HEALTHCARE...|    2093207320|   5|
# |      Andhra Pradesh|SRI VIJAYA VISAKH...|    2129403500|   1|
# |      Andhra Pradesh|NIZAM DECCAN SUGA...|    2011500000|   2|
# |      Andhra Pradesh|SEOYON E-HWA SUMM...|    2011154970|   3|
# |      Andhra Pradesh|KAKINADA SMART CI...|    2000000000|   4|
# |      Andhra Pradesh|GREATER VISAKHAPA...|    2000000000|   4|
# |      Andhra Pradesh|NSL TEXTILES LIMI...|    1932565780|   5|
# |         Lakshadweep|LAKSHADWEEP DEVEL...|      65041000|   1|
# |         Lakshadweep|AMANSHIZ BLUEZONA...|       1000000|   2|
# |         Lakshadweep|WHITESANDS GLOBAL...|       1000000|   2|
# |         Lakshadweep|LAKSHADWEEP TOURI...|        500000|   3|
# |         Lakshadweep|KAVARATTI SMART C...|        500000|   3|
# |         Lakshadweep|BAHR AZRAQ FARMER...|        147500|   4|
# |         Lakshadweep|LAKSHADWEEP COCON...|        100000|   5|
# |         Lakshadweep|MURAADHU MARITIME...|        100000|   5|
# |         Lakshadweep|HAVENS MARKETING ...|        100000|   5|
# |         Lakshadweep|LAKSHADEEP AGRO F...|        100000|   5|
# |         Lakshadweep|WHITESANDS FREIGH...|        100000|   5|
# |         Lakshadweep|INDIGO ISLAND LEI...|        100000|   5|
# |         Lakshadweep|LAKSHADWEEP TOURS...|        100000|   5|
# |         Lakshadweep|K K MEMORIAL PRE ...|        100000|   5|
# |         Lakshadweep|COASTAL SHIPPING ...|        100000|   5|
# |      Madhya Pradesh|BHOPAL SMART CITY...|    2000000000|   1|
# |      Madhya Pradesh|INDORE SMART CITY...|    2000000000|   1|
# |      Madhya Pradesh|JABALPUR SMART CI...|    2000000000|   1|
# |      Madhya Pradesh|GWALIOR SMART CIT...|    2000000000|   1|
# |      Madhya Pradesh|UJJAIN SMART CITY...|    2000000000|   1|
# |      Madhya Pradesh|DIASPARK TECHBUIL...|    1748400620|   2|
# |      Madhya Pradesh|COMMERCIAL ENGINE...|    1699649470|   3|
# |      Madhya Pradesh|MADHYA PRADESH ST...|    1675316000|   4|
# |      Madhya Pradesh|NATIONAL HIGH POW...|    1520000000|   5|
# |              Punjab|RANBAXY LABORATOR...|    2128317485|   1|
# |              Punjab|    J C T LIMITED   |    2096066470|   2|
# |              Punjab|SEMICONDUCTOR COM...|    1884150000|   3|
# |              Punjab|QUARKCITY INDIA P...|    1863913500|   4|
# |              Punjab|PEPSI FOODS PRIVA...|    1854060920|   5|
# |             Manipur|LOKTAK DOWNSTREAM...|    1233923090|   1|
# |             Manipur|NORTH EAST REGION...|     676950000|   2|
# |             Manipur|NEW MILLENIUM HEA...|     220000000|   3|
# |             Manipur|SALAI AGRO PRODUC...|     157492000|   4|
# |             Manipur|SHIJA HOSPITALS A...|     131355500|   5|
# |                 Goa|VMSALGAOCAR HOTEL...|    1802100000|   1|
# |                 Goa|GMR GOA INTERNATI...|    1600000000|   2|
# |                 Goa|CENTURION BANK OF...|    1566856000|   3|
# |                 Goa|SYNTEGON TECHNOLO...|    1501000000|   4|
# |                 Goa|PRINCE PIPES AND ...|    1100257590|   5|
# |             Mizoram|MIZORAM FOOD AND ...|     197830900|   1|
# |             Mizoram|ZORAM INDUSTRIAL ...|     157810000|   2|
# |             Mizoram|NORTH EAST REGION...|     136665000|   3|
# |             Mizoram|ZORAM MEGA FOOD P...|     120932500|   4|
# |             Mizoram|MIZORAM HANDLOOM ...|     100000000|   5|
# |    Himachal Pradesh|MOREPEN LABORATOR...|    2096172506|   1|
# |    Himachal Pradesh|L&T HIMACHAL HYDR...|    2005500000|   2|
# |    Himachal Pradesh| GPI TEXTILES LTD   |    1687541000|   3|
# |    Himachal Pradesh|MALANA POWER COMP...|    1475257310|   4|
# |    Himachal Pradesh|STURDY INDUSTRIES...|    1468507000|   5|
# |             Haryana|NOURISHCO BEVERAG...|    2130000000|   1|
# |             Haryana|NACHI TECHNOLOGY ...|    2100000000|   2|
# |             Haryana|NIDEC INDIA PRIVA...|    2093000000|   3|
# |             Haryana|KEIHIN INDIA MANU...|    2076777000|   4|
# |             Haryana|BAXALTA BIOSCIENC...|    2002376120|   5|
# |   Jammu and Kashmir|JAMMU AND KASHMIR...|     800000000|   1|
# |   Jammu and Kashmir|JAMMU AND KASHMIR...|     556858392|   2|
# |   Jammu and Kashmir|KHYBER INDUSTRIES...|     500000000|   3|
# |   Jammu and Kashmir|JAMMU AND KASHMIR...|     480000000|   4|
# |   Jammu and Kashmir|GI POWER CORPORAT...|     394690000|   5|
# |           Jharkhand|TATA CUMMINS PRIV...|    1800000000|   1|
# |           Jharkhand|TENUGHAT VIDYUT N...|    1050000000|   2|
# |           Jharkhand|BIHAR SPONGE IRON...|     902054030|   3|
# |           Jharkhand|JHARKHAND INFRAST...|     800000000|   4|
# |           Jharkhand|JOST INDIA AUTO C...|     794963550|   5|
# |              Orissa|IDCOL KALINGA IRO...|    1501000000|   1|
# |              Orissa|YAZDANI STEEL & P...|    1358164400|   2|
# |              Orissa|KONARK MET COKE L...|    1327228000|   3|
# |              Orissa|ADHUNIK METALIKS ...|    1234995000|   4|
# |              Orissa|MICRO FINANCE LTD   |    1211318200|   5|
# |   Arunachal Pradesh|ARUNACHAL HYDRO P...|    1643000000|   1|
# |   Arunachal Pradesh|DEVI ENERGIES PRI...|     954808950|   2|
# |   Arunachal Pradesh|T. K. ENGINEERING...|     792124000|   3|
# |   Arunachal Pradesh|RISER & PANEL INF...|     779062030|   4|
# |   Arunachal Pradesh|EVEREST INFRA ENE...|     260110000|   5|
# |             Gujarat|ZYDUS WELLNESS PR...|    2144272980|   1|
# |             Gujarat|ALPS BPO SERVICES...|    2101000000|   2|
# |             Gujarat|ESSAR SHIPPING LI...|    2069760720|   3|
# |             Gujarat|HAZIRA PIPE MILL ...|    2057531330|   4|
# |             Gujarat|ADDLIFE INVESTMEN...|    2050000000|   5|
# |         Uttaranchal|MAHANANDA SPA AND...|    1354921350|   1|
# |         Uttaranchal|SHEEL OIL & FATS ...|    1169474510|   2|
# |         Uttaranchal|SIDCUL CONCOR INF...|    1000000000|   3|
# |           Meghalaya|J.U.D. CEMENTS LT...|     774417200|   5|
# |       Daman and Diu|      PSL LIMITED   |    1249344840|   1|
# |       Daman and Diu|NIRPAN SECURITIES...|     883725000|   2|
# |       Daman and Diu|RADHA MADHAV CORP...|     863422750|   3|
# |       Daman and Diu|DOLAT CAPITAL MAR...|     508776910|   4|
# |       Daman and Diu|CITADELLE AGENCIE...|     425988930|   5|
# |         Maharashtra|AVINASH BHOSALE I...|    2146500000|   1|
# |         Maharashtra|BOI AXA INVESTMEN...|    2146035840|   2|
# |         Maharashtra|BOTHE WINDFARM DE...|    2143750000|   3|
# |         Maharashtra|SONY DADC MANUFAC...|    2142858680|   4|
# |         Maharashtra|MORGAN STANLEY IN...|    2142186050|   5|
# |           Telangana|JADCHERLA EXPRESS...|    2100402530|   1|
# |           Telangana|MYTRAH VAYU (MANJ...|    2084506870|   2|
# |           Telangana|ADITYA HOUSING & ...|    2060000000|   3|
# |           Telangana|GKC PROJECTS LIMI...|    2050787020|   4|
# |           Telangana|DECCAN INFRASTRUC...|    2000000000|   5|
# |           Telangana|NAVA BHARAT ENERG...|    2000000000|   5|
# |         West Bengal|CONCAST STEEL & P...|    2132178800|   1|
# |         West Bengal|BHARAT NRE COKE L...|    2116915590|   2|
# |         West Bengal|THE WEST BENGAL S...|    2116258700|   3|
# |         West Bengal|FORUM PROJECTS PR...|    2019346000|   4|
# |         West Bengal|USHA MARTIN TELEM...|    1975954440|   5|
# |               Bihar|BIHAR STATE HYDRO...|     990400000|   1|
# |               Bihar|PYRITES PHOSPHATE...|     954003000|   2|
# |               Bihar|BHARAT WAGON AND ...|     758487000|   3|
# |               Bihar|HINDUSTAN MEDIA V...|     736715480|   4|
# |               Bihar|SECURITY AND INTE...|     733189870|   5|
# |             Tripura|TRIPURA JUTE MILL...|    1110401000|   1|
# |             Tripura|TRIPURA HANDLOOM ...|     617411400|   2|
# |             Tripura|TRIPURA SMALL IND...|     550581600|   3|
# |             Tripura|TRIPURA TEA DEVEL...|     461467500|   4|
# |             Tripura|TRIPURA NATURAL G...|     300000000|   5|
# |       Uttar Pradesh|      LML LIMITED   |    2004095100|   1|
# |       Uttar Pradesh|SAHARA CARE LIMIT...|    2000000000|   2|
# |       Uttar Pradesh|RAJ CORPORATION L...|    1995444000|   3|
# |       Uttar Pradesh|KANCHAN,S BAKERS ...|    1903000000|   4|
# |       Uttar Pradesh|JUBILANT BIOSYS L...|    1870613000|   5|
# +--------------------+--------------------+--------------+----+

# %%
new_comp.count()
# Out:
# 195

# %%
# new_comp.rdd.repartition(1).orderBy("Registered_State").getNumPartitions()

# %%
new_comp.rdd.coalesce(1).toDF().write.option("header",True).mode("overwrite").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 5. Which state has highest companies registered

# %%
# query 5
highest = df.groupBy("REGISTERED_STATE").agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("no_of_companies")).orderBy(desc("no_of_companies"))
highest.show(1)
# Out:
# +----------------+---------------+
# |REGISTERED_STATE|no_of_companies|
# +----------------+---------------+
# |     Maharashtra|         395282|
# +----------------+---------------+
# only showing top 1 row

# %%
highest.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 6. Find the year on which each state has their maximum registration

# %%
# query 6

# df.groupBy("REGISTERED_STATE").agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("count")).orderBy(desc("count")).show(1000)
date_df = df.select("CORPORATE_IDENTIFICATION_NUMBER",year("date_of_registration").alias("year"),"REGISTERED_STATE")
reg_count = date_df.groupBy("REGISTERED_STATE","year").agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("count")).orderBy(desc("count"))

ptn = Window.partitionBy("REGISTERED_STATE").orderBy(desc("count"))
reg_count = reg_count.withColumn("rank", rank().over(ptn))
reg_count = reg_count.filter(col("rank") == 1).drop("rank")
reg_count.show(2000)
# Out:
# +--------------------+----+------+
# |    REGISTERED_STATE|year| count|
# +--------------------+----+------+
# |            Nagaland|null|   620|
# |           Karnataka|null|125779|
# |Dadra and Nagra H...|null|   550|
# |              Kerala|null| 56098|
# |          Tamil Nadu|null|150871|
# |      Andhra Pradesh|null| 33050|
# |         Lakshadweep|null|    18|
# |      Madhya Pradesh|null| 41318|
# |              Punjab|null| 32440|
# |             Manipur|null|  1056|
# |                 Goa|null|  8942|
# |             Mizoram|null|   175|
# |    Himachal Pradesh|null|  6591|
# |             Haryana|null| 51039|
# |   Jammu and Kashmir|null|  5978|
# |           Jharkhand|null| 15078|
# |              Orissa|null| 27023|
# |   Arunachal Pradesh|null|   629|
# |             Gujarat|null|105554|
# |         Uttaranchal|null|  8924|
# |              Sikkim|null|     2|
# |               Delhi|null|348230|
# |          Chandigarh|null| 15018|
# |         Pondicherry|null|  3454|
# |Andaman and Nicob...|null|   480|
# |           Rajasthan|null| 61370|
# |               Assam|null| 12078|
# |         Chattisgarh|null| 10703|
# |           Meghalaya|null|  1115|
# |       Daman and Diu|null|   397|
# |         Maharashtra|null|395282|
# |           Telangana|null|112401|
# |         West Bengal|null|207005|
# |               Bihar|null| 35920|
# |             Tripura|null|   645|
# |       Uttar Pradesh|null|116337|
# +--------------------+----+------+

# %%
reg_count.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 7. Find the sector that is most common in each state

# %%
# query 7

sec = df.groupBy("REGISTERED_STATE","COMPANY_CLASS").agg(count(col("COMPANY_CLASS")).alias("class_count")).orderBy("REGISTERED_STATE","COMPANY_CLASS")

sec = sec.filter(col("COMPANY_CLASS").isNotNull())

wind = Window.partitionBy("REGISTERED_STATE").orderBy(desc("class_count"))
sec = sec.withColumn("rank", rank().over(wind))
sec = sec.filter(col("rank") == 1).orderBy("REGISTERED_STATE").drop("rank") # take the max count of sector in each state; alphabetical order
sec.show()
# Out:
# +--------------------+-------------+-----------+
# |    REGISTERED_STATE|COMPANY_CLASS|class_count|
# +--------------------+-------------+-----------+
# |Andaman and Nicob...|      Private|        460|
# |      Andhra Pradesh|      Private|      30538|
# |   Arunachal Pradesh|      Private|        582|
# |               Assam|      Private|      10816|
# |               Bihar|      Private|      32176|
# |          Chandigarh|      Private|      13248|
# |         Chattisgarh|      Private|       9835|
# |Dadra and Nagra H...|      Private|        442|
# |       Daman and Diu|      Private|        318|
# |               Delhi|      Private|     322131|
# |                 Goa|      Private|       8421|
# |             Gujarat|      Private|      95834|
# |             Haryana|      Private|      47457|
# |    Himachal Pradesh|      Private|       5896|
# |   Jammu and Kashmir|      Private|       5430|
# |           Jharkhand|      Private|      13899|
# |           Karnataka|      Private|     117309|
# |              Kerala|      Private|      51449|
# |         Lakshadweep|      Private|         17|
# |      Madhya Pradesh|      Private|      37677|
# +--------------------+-------------+-----------+
# only showing top 20 rows

# %%
sec.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 8. Based on sub_category give the count for companies in each state

# %%
# query 8

cat = df.groupBy("REGISTERED_STATE","COMPANY_SUB_CATEGORY").agg(count(col("COMPANY_SUB_CATEGORY")).alias("category_count")).orderBy("REGISTERED_STATE","COMPANY_SUB_CATEGORY")

cat = cat.filter(col("COMPANY_SUB_CATEGORY").isNotNull())
cat.show()
# Out:
# +--------------------+--------------------+--------------+
# |    REGISTERED_STATE|COMPANY_SUB_CATEGORY|category_count|
# +--------------------+--------------------+--------------+
# |Andaman and Nicob...|    Non-govt company|           477|
# |Andaman and Nicob...|  State Govt company|             2|
# |Andaman and Nicob...|  Union Govt company|             1|
# |      Andhra Pradesh|Guarantee and Ass...|             8|
# |      Andhra Pradesh|    Non-govt company|         32742|
# |      Andhra Pradesh|  State Govt company|            76|
# |      Andhra Pradesh|Subsidiary of For...|           145|
# |      Andhra Pradesh|  Union Govt company|             4|
# |   Arunachal Pradesh|    Non-govt company|           618|
# |   Arunachal Pradesh|  State Govt company|            11|
# |               Assam|Guarantee and Ass...|             6|
# |               Assam|    Non-govt company|         12004|
# |               Assam|  State Govt company|            54|
# |               Assam|Subsidiary of For...|             2|
# |               Assam|  Union Govt company|            10|
# |               Bihar|Guarantee and Ass...|            19|
# |               Bihar|    Non-govt company|         35790|
# |               Bihar|  State Govt company|            91|
# |               Bihar|Subsidiary of For...|             3|
# |               Bihar|  Union Govt company|             6|
# +--------------------+--------------------+--------------+
# only showing top 20 rows

# %%
cat.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 9. List the companies that have been recently enrolled in each state

# %%
# query 9

rec_comp = df.select("REGISTERED_STATE","COMPANY_NAME","date_of_registration").filter(col("date_of_registration").isNotNull())
# df.select("date_of_registration").show(2000)
# rec_comp = rec_comp.filter(col("year").isNotNull())

# df.groupBy("REGISTERED_STATE")

wind = Window.partitionBy("REGISTERED_STATE").orderBy(desc("date_of_registration"))
rec_comp = rec_comp.withColumn("rank", dense_rank().over(wind))
rec_comp.filter(col("rank").between(1,5)).show(2000)
# Out:
# +--------------------+--------------------+--------------------+----+
# |    REGISTERED_STATE|        COMPANY_NAME|date_of_registration|rank|
# +--------------------+--------------------+--------------------+----+
# |            Nagaland|JENELO FOODS PRIV...|          2020-01-30|   1|
# |            Nagaland|KAPUNU HOME (OPC)...|          2020-01-13|   2|
# |            Nagaland|NUH FUTURISTIC PR...|          2020-01-07|   3|
# |            Nagaland|AWESOME BUTCHER P...|          2020-01-07|   3|
# |            Nagaland|ONGBOU MARKETING ...|          2019-12-18|   4|
# |            Nagaland|SEITHOGEI FOUNDAT...|          2019-12-06|   5|
# |           Karnataka|RAIVO INFRA PRIVA...|          2020-01-31|   1|
# |           Karnataka|PROPOFF MANAGEMEN...|          2020-01-31|   1|
# |           Karnataka|GINEE MARKETING A...|          2020-01-31|   1|
# |           Karnataka|APHELION HEALTH P...|          2020-01-31|   1|
# |           Karnataka|KBN SERVICES PRIV...|          2020-01-31|   1|
# |           Karnataka|OHM PROGENITOR PR...|          2020-01-31|   1|
# |           Karnataka|WEBBIRTH PRIVATE ...|          2020-01-31|   1|
# |           Karnataka|SHALINI GOVIL RAD...|          2020-01-31|   1|
# |           Karnataka|COMMERCECREW ACCO...|          2020-01-31|   1|
# |           Karnataka|KOFLUENCE TECH PR...|          2020-01-31|   1|
# |           Karnataka|NEW HORIZON HUMAN...|          2020-01-31|   1|
# |           Karnataka|GIGLABZ PRIVATE L...|          2020-01-31|   1|
# |           Karnataka|CLEAP ENGINEERING...|          2020-01-31|   1|
# |           Karnataka|USC WORLDWIDE PRI...|          2020-01-31|   1|
# |           Karnataka|TAAZACITY VENTURE...|          2020-01-31|   1|
# |           Karnataka|YELLOWZONE CAB PR...|          2020-01-31|   1|
# |           Karnataka|TULIO VACATIONS P...|          2020-01-31|   1|
# |           Karnataka|BLU-PHOENIX MANAG...|          2020-01-31|   1|
# |           Karnataka|REO EVENTS PRIVAT...|          2020-01-31|   1|
# |           Karnataka|TECHWORKSLAB PRIV...|          2020-01-31|   1|
# |           Karnataka|LEITEN CONSULTING...|          2020-01-31|   1|
# |           Karnataka|LETSGRAD LABS PRI...|          2020-01-31|   1|
# |           Karnataka|COBTECH SERVICES ...|          2020-01-31|   1|
# |           Karnataka|GREENMAX RECYCLIN...|          2020-01-31|   1|
# |           Karnataka|KBASS MARKETING P...|          2020-01-31|   1|
# |           Karnataka|DC KUSUMITHA BUIL...|          2020-01-31|   1|
# |           Karnataka|IDSQUARE TECHNOLO...|          2020-01-31|   1|
# |           Karnataka|BST COURIER PRIVA...|          2020-01-31|   1|
# |           Karnataka|JANAABHIWRIDDI NI...|          2020-01-31|   1|
# |           Karnataka|SBS LEAF (OPC) PR...|          2020-01-31|   1|
# |           Karnataka|SUBHA FARMS PRIVA...|          2020-01-31|   1|
# |           Karnataka|ZSAH INDIA PRIVAT...|          2020-01-31|   1|
# |           Karnataka|CASHPECASH TECHNO...|          2020-01-31|   1|
# |           Karnataka|CLICKGO TECHNOLOG...|          2020-01-31|   1|
# |           Karnataka|BRANDEE COMMERCE ...|          2020-01-31|   1|
# |           Karnataka|CMMT TECHNOLOGIES...|          2020-01-31|   1|
# |           Karnataka|CONSEQUOR COPIOSE...|          2020-01-31|   1|
# |           Karnataka|KEPIO ENGINEERING...|          2020-01-31|   1|
# |           Karnataka|COGNIFO TECHNOLOG...|          2020-01-31|   1|
# |           Karnataka|A2ZCLOUDDBA SOLUT...|          2020-01-31|   1|
# |           Karnataka|JEETONE TECHNOLOG...|          2020-01-31|   1|
# |           Karnataka|TEQLINX SOFTWARE ...|          2020-01-31|   1|
# |           Karnataka|BEADS MAZE SOLUTI...|          2020-01-31|   1|
# |           Karnataka|KASUKURTHI HEALTH...|          2020-01-31|   1|
# |           Karnataka|SIMPLICONTRACT TE...|          2020-01-31|   1|
# |           Karnataka|PERFECTLY IMPERFE...|          2020-01-31|   1|
# |           Karnataka|DEX COWORK (OPC) ...|          2020-01-30|   2|
# |           Karnataka|OFFPROP MANAGEMEN...|          2020-01-30|   2|
# |           Karnataka|WISEAIR ENERGY PR...|          2020-01-30|   2|
# |           Karnataka|PRANAVAM INFOTECH...|          2020-01-30|   2|
# |           Karnataka|VARSHA BIOTECH PR...|          2020-01-30|   2|
# |           Karnataka|VINFOCATIONS (OPC...|          2020-01-30|   2|
# |           Karnataka|SELLMETRIC PRIVAT...|          2020-01-30|   2|
# |           Karnataka|DYNAMIXE DIGITAL ...|          2020-01-30|   2|
# |           Karnataka|BALAJI AND ASHOK ...|          2020-01-30|   2|
# |           Karnataka|OBLIBENY PRIVATE ...|          2020-01-30|   2|
# |           Karnataka|C&N LABORATORIES ...|          2020-01-30|   2|
# |           Karnataka|GROOMING GURUKUL ...|          2020-01-30|   2|
# |           Karnataka|KASPAROV CONSULTI...|          2020-01-30|   2|
# |           Karnataka|ELEGENT LEARNING ...|          2020-01-30|   2|
# |           Karnataka|EVENTELL GLOBAL S...|          2020-01-30|   2|
# |           Karnataka|SPWAVE PRIVATE LI...|          2020-01-30|   2|
# |           Karnataka|VIJAYALAKSHMI DIS...|          2020-01-30|   2|
# |           Karnataka|KGF BUILDERS AND ...|          2020-01-30|   2|
# |           Karnataka|DIGITAL GEMBA SOF...|          2020-01-30|   2|
# |           Karnataka|VARNAKI PRIVATE L...|          2020-01-30|   2|
# |           Karnataka|VARSHA STONES INT...|          2020-01-30|   2|
# |           Karnataka|KEFFOS INDIA PRIV...|          2020-01-30|   2|
# |           Karnataka|SMARTPOD TECHNOLO...|          2020-01-30|   2|
# |           Karnataka|ANJUS HOMEKITCHEN...|          2020-01-30|   2|
# |           Karnataka|BRYMAX GLOBAL PRI...|          2020-01-30|   2|
# |           Karnataka|BAKERPOPS PRIVATE...|          2020-01-30|   2|
# |           Karnataka|EDUX TECHNOLOGIES...|          2020-01-30|   2|
# |           Karnataka|PHYTO EDUTECH PRI...|          2020-01-30|   2|
# |           Karnataka|SKILLFIX CONSULTA...|          2020-01-30|   2|
# |           Karnataka|BASILIC PHARMACEU...|          2020-01-30|   2|
# |              Kerala|INIT SOLUTIONS PR...|          2020-01-31|   1|
# |              Kerala|FELLOWED TECHNOLO...|          2020-01-31|   1|
# |              Kerala|TIRONTEC SOFTWARE...|          2020-01-31|   1|
# |              Kerala|NMSR MOTORS PRIVA...|          2020-01-31|   1|
# |              Kerala|CLIMATE FACTORY P...|          2020-01-30|   2|
# |              Kerala|INDALIUM STEELS P...|          2020-01-30|   2|
# |              Kerala|CBS CORPORATE BUS...|          2020-01-30|   2|
# |              Kerala|VISIONMR ENGINEER...|          2020-01-30|   2|
# |              Kerala|DIVAKARAN INFRAST...|          2020-01-30|   2|
# |              Kerala|RRACA CONSULTING ...|          2020-01-30|   2|
# |              Kerala|MJS SAND AND ROCK...|          2020-01-30|   2|
# |              Kerala|PULLOLIL ROCK PRO...|          2020-01-30|   2|
# |              Kerala|PULLOLIL STONES P...|          2020-01-30|   2|
# |              Kerala|PRIVILE FOOD PROD...|          2020-01-30|   2|
# |              Kerala|AZAD SPICE GARDEN...|          2020-01-30|   2|
# |              Kerala|JACQUA ENVIRO SYS...|          2020-01-30|   2|
# |              Kerala|AMDELAA MOBILITY ...|          2020-01-30|   2|
# |              Kerala|PRIMEX ANIMATION ...|          2020-01-30|   2|
# |              Kerala|HYBONE MEDICAL PR...|          2020-01-30|   2|
# |              Kerala|KS2 FOOD PRODUCTS...|          2020-01-30|   2|
# |              Kerala|SIBLIC PRIVATE LI...|          2020-01-30|   2|
# |              Kerala|VASTHRA ASSOCIATE...|          2020-01-30|   2|
# |              Kerala|HIWAGA HR SERVICE...|          2020-01-30|   2|
# |              Kerala|RESPONSE PLUS MED...|          2020-01-30|   2|
# |              Kerala|CETARC PRIVATE LI...|          2020-01-30|   2|
# |              Kerala|EVANTO SERVICES P...|          2020-01-30|   2|
# |              Kerala|MASTERCODE TECHNO...|          2020-01-30|   2|
# |              Kerala|DRAKON INNOVATION...|          2020-01-30|   2|
# |              Kerala|ZEN APP STUDIO PR...|          2020-01-30|   2|
# |              Kerala|CPSE (INDIA) PRIV...|          2020-01-30|   2|
# |              Kerala|ESES PLANNET PRIV...|          2020-01-30|   2|
# |              Kerala|MAANYA ASSOCIATES...|          2020-01-30|   2|
# |              Kerala|PANATHUR IOHRP AG...|          2020-01-29|   3|
# |              Kerala|SICHER ELEVATORS ...|          2020-01-29|   3|
# |              Kerala|RAHEENA PROPERTIE...|          2020-01-29|   3|
# |              Kerala|RECON ENERGY INDI...|          2020-01-29|   3|
# |              Kerala|VANIMAL ROCK PROD...|          2020-01-29|   3|
# |              Kerala|PARAKKADAVU GRANI...|          2020-01-29|   3|
# |              Kerala|PLAYON KOCHI PRIV...|          2020-01-29|   3|
# |              Kerala|MARANIS INDIA PRI...|          2020-01-29|   3|
# |              Kerala|AVVENIRE TRADING ...|          2020-01-29|   3|
# |              Kerala|EVAL TRADING PRIV...|          2020-01-29|   3|
# |              Kerala|VINIECO PRODUCTS ...|          2020-01-29|   3|
# |              Kerala|BBEEZ NUCLEAR TEC...|          2020-01-29|   3|
# |         Chattisgarh|CALIDAD HEALTHCAR...|          2020-01-31|   1|
# |         Chattisgarh|CONSTA CLOUD PRIV...|          2020-01-31|   1|
# |         Chattisgarh|SSTL INDIA PRIVAT...|          2020-01-30|   2|
# |         Chattisgarh|MOCHOHAAT MERCHAN...|          2020-01-30|   2|
# |         Chattisgarh|DEVI WOMAN AND CH...|          2020-01-30|   2|
# |         Chattisgarh|SUMIT HEALTHTECH ...|          2020-01-30|   2|
# |         Chattisgarh|NARAIN ENGINEERIN...|          2020-01-29|   3|
# |         Chattisgarh|RAVINDRAV (OPC) P...|          2020-01-29|   3|
# |         Chattisgarh|SWIPEWIRE (OPC) P...|          2020-01-29|   3|
# |         Chattisgarh|BUNDELAS ENTERPRI...|          2020-01-29|   3|
# |         Chattisgarh|MANGAL SHREE PROD...|          2020-01-29|   3|
# |         Chattisgarh|CIRCLE SKINCARE P...|          2020-01-29|   3|
# |         Chattisgarh|KALYAN FACILITY S...|          2020-01-29|   3|
# |         Chattisgarh|STERLINGSOUL SOFT...|          2020-01-28|   4|
# |         Chattisgarh|PIRAMAL BIOFUELS ...|          2020-01-28|   4|
# |         Chattisgarh|SHRI NIRANJANAM I...|          2020-01-28|   4|
# |         Chattisgarh|REDTIE CUISINE PR...|          2020-01-28|   4|
# |         Chattisgarh|SHUNJALL COLD STO...|          2020-01-28|   4|
# |         Chattisgarh|AADIBHOOMI ORGANI...|          2020-01-27|   5|
# |         Chattisgarh|MAA KUDARGARHI PO...|          2020-01-27|   5|
# |         Chattisgarh|CHHATTISGARH STAT...|          2020-01-27|   5|
# |         Chattisgarh|RAMAYA VEG16 PRIV...|          2020-01-27|   5|
# |         Chattisgarh|IRON2KING DOT ONL...|          2020-01-27|   5|
# |         Chattisgarh|BASTAR BRICKSTONE...|          2020-01-27|   5|
# |         Chattisgarh|KANCHANDAS AND SO...|          2020-01-27|   5|
# |           Meghalaya|NORTH EASTERN SON...|          2020-01-10|   1|
# |           Meghalaya|SAWKHER AGRO PRIV...|          2019-12-31|   2|
# |           Meghalaya|UNTREW MOTEL AND ...|          2019-12-25|   3|
# |           Meghalaya|ROILANG HOTELS PR...|          2019-12-12|   4|
# |           Meghalaya|MOUNT RIDGE PRIVA...|          2019-12-03|   5|
# |           Meghalaya|MAXIM INFRASTRUCT...|          2019-12-03|   5|
# |       Daman and Diu|KINDLE BROKING PR...|          2020-01-08|   1|
# |       Daman and Diu|SURJECTIVE TECHNO...|          2019-12-04|   2|
# |       Daman and Diu|PURE GREENTECH IN...|          2019-11-21|   3|
# |       Daman and Diu|SECUREPLAST PRIVA...|          2019-11-05|   4|
# |       Daman and Diu|FLAIR WRITING EQU...|          2019-11-04|   5|
# |         Maharashtra|WHITTLE SPINNING ...|          5600-02-01|   1|
# |         Maharashtra|ADIKALA VENTURES ...|          2020-01-31|   2|
# |         Maharashtra|CHANAKYA ACCOUNTS...|          2020-01-31|   2|
# |         Maharashtra|REALFARM ORGANIC ...|          2020-01-31|   2|
# |         Maharashtra|TOBLER INDIA PRIV...|          2020-01-31|   2|
# |         Maharashtra|POLYMERLINK INDIA...|          2020-01-31|   2|
# |         Maharashtra|EGOODS INDIA PRIV...|          2020-01-31|   2|
# |         Maharashtra|NIKHARVA CHEMICAL...|          2020-01-31|   2|
# |         Maharashtra|KAYSARIYA AGRO IN...|          2020-01-31|   2|
# |         Maharashtra|MOLECULAR SYNTHES...|          2020-01-31|   2|
# |         Maharashtra|ONEDIRECTION SERV...|          2020-01-31|   2|
# |         Maharashtra|MIREN EXPORTS PRI...|          2020-01-31|   2|
# |         Maharashtra|SHEETAL HOSPITALI...|          2020-01-31|   2|
# |         Maharashtra|CREED INDIA PROCE...|          2020-01-31|   2|
# |         Maharashtra|MANALI RESORT & B...|          2020-01-31|   2|
# |         Maharashtra|REALSTONE INFRA L...|          2020-01-31|   2|
# |         Maharashtra|BHARAT AEROTECH P...|          2020-01-31|   2|
# |         Maharashtra|ROOMEEGO TECHNOLO...|          2020-01-31|   2|
# |         Maharashtra|OM SHIVA MALHAR B...|          2020-01-31|   2|
# |         Maharashtra|ALL ABODE LIVING ...|          2020-01-31|   2|
# |         Maharashtra|VINSON LOGISTICS ...|          2020-01-31|   2|
# |         Maharashtra|GV TECHNO PLAST P...|          2020-01-31|   2|
# |         Maharashtra|SOBA LOGISTICS IN...|          2020-01-31|   2|
# |         Maharashtra|AAD TECH ENVIRON ...|          2020-01-31|   2|
# |         Maharashtra|SANKALP LOGITRANS...|          2020-01-31|   2|
# |         Maharashtra|AIRQON ENGINEERIN...|          2020-01-31|   2|
# |         Maharashtra|JAAUDEVACHIYAGAVA...|          2020-01-31|   2|
# |         Maharashtra|SOLITUDE ENGINEER...|          2020-01-31|   2|
# |         Maharashtra|BANDHILAKI FOUNDA...|          2020-01-31|   2|
# |         Maharashtra|PALWAN AGRO PRODU...|          2020-01-31|   2|
# |         Maharashtra|LOK KALYAN VIKAS ...|          2020-01-31|   2|
# |         Maharashtra|INDICANN AGRO CON...|          2020-01-31|   2|
# |         Maharashtra|SUVIHITA VISHWASA...|          2020-01-31|   2|
# |         Maharashtra|PANCHKRUSHI FARME...|          2020-01-31|   2|
# |         Maharashtra|MADURA FOUNDATION   |          2020-01-31|   2|
# |         Maharashtra|FRESH TRADITIONAL...|          2020-01-31|   2|
# |         Maharashtra|WORLD VEGAN VISIO...|          2020-01-31|   2|
# |         Maharashtra|AARANYA HERBALS (...|          2020-01-31|   2|
# |         Maharashtra|UPAJ HEALTHCARE P...|          2020-01-31|   2|
# |         Maharashtra|SGD POLYPLAST PRI...|          2020-01-31|   2|
# |         Maharashtra|SOUND & VISION IN...|          2020-01-31|   2|
# |         Maharashtra|INSIDIOUS ESPORTS...|          2020-01-31|   2|
# |         Maharashtra|RNP STUDIOS ENTER...|          2020-01-31|   2|
# |         Maharashtra|REVENTURE FUNWARE...|          2020-01-31|   2|
# |         Maharashtra|MULTI THINK TEAM ...|          2020-01-31|   2|
# |         Maharashtra|YOKE SERVICES PRI...|          2020-01-31|   2|
# |         Maharashtra|FUELME INDIA PRIV...|          2020-01-31|   2|
# |         Maharashtra|VELAHAK ENTERPRIS...|          2020-01-31|   2|
# |         Maharashtra|RUCHI COUNTRY BAR...|          2020-01-31|   2|
# |         Maharashtra|AKV MULTITRADE PR...|          2020-01-31|   2|
# |         Maharashtra|FOODPOT PRIVATE L...|          2020-01-31|   2|
# |         Maharashtra|PASAYDAN GUEST HO...|          2020-01-31|   2|
# |         Maharashtra|PRIDE PHYSICAL ED...|          2020-01-31|   2|
# |         Maharashtra|NEXTEDGE BUSINESS...|          2020-01-31|   2|
# |         Maharashtra|NAVED GLOBAL SCHO...|          2020-01-31|   2|
# |         Maharashtra|SURGIMED CART PRI...|          2020-01-31|   2|
# |         Maharashtra|JETS FITNESS & SP...|          2020-01-31|   2|
# |         Maharashtra|HOSTELNEED E-CART...|          2020-01-31|   2|
# |         Maharashtra|BEE LIFE SERVICES...|          2020-01-31|   2|
# |         Maharashtra|INDISHINE COUTURE...|          2020-01-31|   2|
# |         Maharashtra|VARAINYA SHOUJIKI...|          2020-01-31|   2|
# |         Maharashtra|PROCFORCE BUSINES...|          2020-01-31|   2|
# |         Maharashtra|TOIING INTERNATIO...|          2020-01-31|   2|
# |         Maharashtra|ALTFREEN ENTERPRI...|          2020-01-31|   2|
# |         Maharashtra|HUDA FOODS PRIVAT...|          2020-01-31|   2|
# |         Maharashtra|GLINT ENTERPRISES...|          2020-01-31|   2|
# |         Maharashtra|FANBUFF ESPORTS I...|          2020-01-31|   2|
# |         Maharashtra|DIGITAL DOGS CONT...|          2020-01-31|   2|
# |         Maharashtra|UNEEFY INTRATECH ...|          2020-01-31|   2|
# |         Maharashtra|UNICORN INSIGHTS ...|          2020-01-31|   2|
# |         Maharashtra|MELGHAT ECO AND A...|          2020-01-31|   2|
# |         Maharashtra|3D DECOR PRIVATE ...|          2020-01-31|   2|
# |         Maharashtra|PRAKAYA MANUFACTU...|          2020-01-31|   2|
# |         Maharashtra|CALCULUS LOGISTIC...|          2020-01-31|   2|
# |         Maharashtra|FALMOUTH MARINE M...|          2020-01-31|   2|
# |         Maharashtra|REOX ELECTRO TECH...|          2020-01-31|   2|
# |         Maharashtra|KAUSHALYA SANGOPA...|          2020-01-31|   2|
# |         Maharashtra|EASYPAY FINANCIAL...|          2020-01-31|   2|
# |         Maharashtra|UMAP PAISA MANAGE...|          2020-01-31|   2|
# |         Maharashtra|ANAVRIN VENTURES ...|          2020-01-31|   2|
# |         Maharashtra|SPOHOZ (OPC) PRIV...|          2020-01-31|   2|
# |         Maharashtra|DREAMJUNCTION TEC...|          2020-01-31|   2|
# |         Maharashtra|SRIYAAN TECHNOLOG...|          2020-01-31|   2|
# |         Maharashtra|MYNTRABULLS TECHN...|          2020-01-31|   2|
# |         Maharashtra|ARTIPIXIAL CREATI...|          2020-01-31|   2|
# |         Maharashtra|YOTIES HITECH PRI...|          2020-01-31|   2|
# |         Maharashtra|NEXWEAVE TECHNOLO...|          2020-01-31|   2|
# |         Maharashtra|GAMESBYTE PRIVATE...|          2020-01-31|   2|
# |         Maharashtra|PLAYBOOK SOFTWARE...|          2020-01-31|   2|
# |         Maharashtra|BOAYED PROJECTS P...|          2020-01-31|   2|
# |         Maharashtra|NICTER INFRASTRUC...|          2020-01-31|   2|
# |         Maharashtra|BRAINLARK KNOWLED...|          2020-01-31|   2|
# |         Maharashtra|ASMITA BROADCASTI...|          2020-01-31|   2|
# |         Maharashtra|24TH CENTURY INTE...|          2020-01-31|   2|
# |         Maharashtra|TCRC PETROLABS BH...|          2020-01-31|   2|
# |         Maharashtra|GRAND INSIGHTS PR...|          2020-01-31|   2|
# |         Maharashtra|OM SAI OM CONSTRU...|          2020-01-31|   2|
# |         Maharashtra|SAKKSHAM INFRASTR...|          2020-01-31|   2|
# |         Maharashtra|CITIZEN ABROAD TA...|          2020-01-31|   2|
# |         Maharashtra|ZEEVA FASHION PRI...|          2020-01-31|   2|
# |         Maharashtra|BLUE GRIVA APPARE...|          2020-01-31|   2|
# |         Maharashtra|GREENGLOBE FUEL S...|          2020-01-31|   2|
# |         Maharashtra|VISH N KAPS FOODS...|          2020-01-31|   2|
# |         Maharashtra|AVAN ENGINEERING ...|          2020-01-31|   2|
# |         Maharashtra|DREAMS POINT MARK...|          2020-01-31|   2|
# |         Maharashtra|RAB RIDE PRIVATE ...|          2020-01-31|   2|
# |         Maharashtra|FINTACTIC ADVISOR...|          2020-01-31|   2|
# |         Maharashtra|PROLEADCYCLE MARK...|          2020-01-31|   2|
# |         Maharashtra|SHREEISHWARBHARTI...|          2020-01-31|   2|
# |         Maharashtra|ARYS CONSULTANCY ...|          2020-01-31|   2|
# |         Maharashtra|EURODIVISAS INDIA...|          2020-01-31|   2|
# |         Maharashtra|SMMORT NIDHI LIMI...|          2020-01-31|   2|
# |         Maharashtra|HAM ENGINEERING P...|          2020-01-31|   2|
# |         Maharashtra|VARADRAJ CONTRACT...|          2020-01-31|   2|
# |         Maharashtra|FIRST INDIA PERSI...|          2020-01-31|   2|
# |         Maharashtra|GREENCAST WALLING...|          2020-01-31|   2|
# |         Maharashtra|VRIHA INFOTECH PR...|          2020-01-31|   2|
# |         Maharashtra|MUSALE DEVELOPERS...|          2020-01-31|   2|
# |         Maharashtra|BIKE24 TWO WHEELE...|          2020-01-31|   2|
# |         Maharashtra|NAVINYA MAHILA FA...|          2020-01-30|   3|
# |         Maharashtra|FORTUNEPAL PRIVAT...|          2020-01-30|   3|
# |         Maharashtra|AGK AGRO FARMERS ...|          2020-01-30|   3|
# |         Maharashtra|HESTY VENTURES PR...|          2020-01-30|   3|
# |         Maharashtra|OXIGRACE CREATION...|          2020-01-30|   3|
# |         Maharashtra|KASHYAPI VENTURES...|          2020-01-30|   3|
# |         Maharashtra|PANDAVGIRI AGRO P...|          2020-01-30|   3|
# |         Maharashtra|CASSIOPEIA SERVIC...|          2020-01-30|   3|
# |         Maharashtra|MAKHALE FARMER PR...|          2020-01-30|   3|
# |         Maharashtra|KARAK ENTERPRISES...|          2020-01-30|   3|
# |         Maharashtra|MANAV MANTRA INDI...|          2020-01-30|   3|
# |         Maharashtra|SPACETIME ACADEMY...|          2020-01-30|   3|
# |         Maharashtra|SIDHAN EDUHUB (OP...|          2020-01-30|   3|
# |         Maharashtra|IX ACADEMY PRIVAT...|          2020-01-30|   3|
# |         Maharashtra|SAMATA EDUCATIONA...|          2020-01-30|   3|
# |         Maharashtra|TEACH-RICH EDUCAT...|          2020-01-30|   3|
# |         Maharashtra|COZMAA HEALTH AND...|          2020-01-30|   3|
# |         Maharashtra|CHITRAKSH E-VEHIC...|          2020-01-30|   3|
# |         Maharashtra|DABHOLKAR RENEWAB...|          2020-01-30|   3|
# |         Maharashtra|YUGANDHARA SOLAR ...|          2020-01-30|   3|
# |         Maharashtra|SOJWAL INDUSTRIES...|          2020-01-30|   3|
# |         Maharashtra|N.Z. EXPORT AND I...|          2020-01-30|   3|
# |         Maharashtra|ATR TRADE RESOURC...|          2020-01-30|   3|
# +--------------------+--------------------+--------------------+----+
# only showing top 2000 rows

# %%
rec_comp.count()
# Out:
# 1989645

# %%
# rec_comp.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 10. Find the count of companies per company_status

# %%
# query 10

comp_count = df.select("CORPORATE_IDENTIFICATION_NUMBER","COMPANY_STATUS") \
    .groupBy("COMPANY_STATUS").agg(count(col("CORPORATE_IDENTIFICATION_NUMBER")).alias("count")).orderBy(desc("count"))

# %%
comp_count.show(2000)
# Out:
# +--------------+-------+
# |COMPANY_STATUS|  count|
# +--------------+-------+
# |          ACTV|1190101|
# |          STOF| 688886|
# |          UPSO|  41457|
# |          AMAL|  24893|
# |          CLLP|  13175|
# |          DISD|   9769|
# |          NAEF|   9286|
# |          ULQD|   6460|
# |          CLLD|   4874|
# |          D455|   2145|
# |          LIQD|   1121|
# |          DRMT|      2|
# |          MLIQ|      1|
# +--------------+-------+

# %%
comp_count.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 11. Find the top 2 companies per principal business activity in 19th century

# %%
# query 11

buis = df.filter(year("date_of_registration").between(1800,1899))


buis = buis.select("PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN","COMPANY_NAME","PAIDUP_CAPITAL")
pt = Window.partitionBy("PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN").orderBy(desc("PAIDUP_CAPITAL"))

buis = buis.withColumn("rank", rank().over(pt)) \
        .filter(col("rank").between(1,2))\
        .drop("rank") 

buis.show()
# Out:
# +--------------------------------------+--------------------+--------------+
# |PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN|        COMPANY_NAME|PAIDUP_CAPITAL|
# +--------------------------------------+--------------------+--------------+
# |                  Agriculture & allied|NEW CHUMTA TEA CO...|      21400000|
# |                  Agriculture & allied|NORTHERN BENGAL T...|      20506000|
# |                  Wholesale and ret...|HOWRAH MILLS CO L...|      64443070|
# |                  Wholesale and ret...|ALLIANCE UDYOG LT...|       6000000|
# |                          Construction|AHMEDNAGAR IMARAT...|        500000|
# |                          Construction|BACHITTER SINGH A...|        414000|
# |                  Other community s...| WHELER CLUB LTD.   |       2130021|
# |                  Other community s...|  OOTACAMUND CLUB   |             0|
# |                  Other community s...|OOTACAMUND GYMKHA...|             0|
# |                  Other community s...|     MALABAR CLUB   |             0|
# |                  Other community s...|THE UPPER INDIA C...|             0|
# |                  Other community s...|THE BENARES CLUB ...|             0|
# |                  Other community s...|THE MAHOMED BAGH ...|             0|
# |                  Real estate renti...|    D C M LIMITED   |     186746315|
# |                  Real estate renti...|THE GROB TEA CO L...|      11623300|
# |                  Hotels and restau...|CACHAR CLUB CO LT...|      23605300|
# |                  Health and social...|JALPAIGURI CLUB C...|         98410|
# |                  Extraterritorial ...|BOMBAY BURMAH TRA...|     139543800|
# |                  Extraterritorial ...|THE DECCAN PAPER ...|       2387500|
# |                  Financial interme...|SRIMAN MADHWA SID...|      64693490|
# +--------------------------------------+--------------------+--------------+
# only showing top 20 rows

# %%
buis.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")

# %% [markdown]
# 12. Find the company with higest paidup capital in each decade

# %%
# query 12

p_cap = df.select("COMPANY_NAME", (floor(year("date_of_registration")/10)*10).alias("decade"),"PAIDUP_CAPITAL").orderBy(desc("decade"))

w = Window.partitionBy("decade").orderBy(desc("PAIDUP_CAPITAL"))

p_cap = p_cap.withColumn("rank", rank().over(w)) \
    .filter(col("rank") == 1).orderBy("decade") \
    .drop("rank")
    
p_cap = p_cap.select("decade","COMPANY_NAME","PAIDUP_CAPITAL").filter(col("decade").isNotNull())
p_cap.show()
# Out:
# +------+--------------------+--------------+
# |decade|        COMPANY_NAME|PAIDUP_CAPITAL|
# +------+--------------------+--------------+
# |  1850|JHUNJHUNU COMMERC...|          2000|
# |  1860|BOMBAY BURMAH TRA...|     139543800|
# |  1870|PENINSULA LAND LI...|     559000000|
# |  1880|    D C M LIMITED   |     186746315|
# |  1890|CENTURY TEXTILES ...|    1116900000|
# |  1900|THE INDIAN HOTELS...|    1189258445|
# |  1910|THE KARUR VYSYA B...|    1598641438|
# |  1920|THE SOUTH INDIAN ...|    1809722151|
# |  1930|SHREENIWAS COTTON...|    1986166600|
# |  1940|    J C T LIMITED   |    2096066470|
# |  1950|MAWMLUH-CHERRA CE...|    1628285140|
# |  1960|RANBAXY LABORATOR...|    2128317485|
# |  1970|KERALA STATE ELEC...|    2035518100|
# |  1980|AVINASH BHOSALE I...|    2146500000|
# |  1990|SONY DADC MANUFAC...|    2142858680|
# |  2000|BOI AXA INVESTMEN...|    2146035840|
# |  2010|SBESS SERVICES PR...|    2145926750|
# |  2020|ATLBATTERY TECHNO...|    1793500000|
# |  5600|WHITTLE SPINNING ...|             0|
# |  9070|958U INFOTECH PRI...|             0|
# +------+--------------------+--------------+

# %%
p_cap.rdd.coalesce(1).toDF().write.option("header",True).mode("append").csv("/user/kolpurath6035/viznu")
